# %%
import os
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# 🔑 Step 1: Set your OpenAI API key
os.environ["OPENAI_API_KEY"] = "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"  # Replace with your actual key

# 🧠 Step 2: Create the prompt
prompt = ChatPromptTemplate.from_template("Write a {style} poem about {topic}.")

# 💬 Step 3: Load the LLM model
llm = ChatOpenAI(model="gpt-4o-mini")

# 🔗 Step 4: Combine (Prompt → Model)
chain = prompt | llm

# 🚀 Step 5: Run it
response = chain.invoke({"style": "legacy", "topic": "virat"})

# 🖨️ Step 6: Print output
print(response.content)
# Out:
# **Virat: A Legacy in Motion**
#
# In the heart of a nation, a hero arose,
# With bat in hand, he wove dreams from prose.
# From streets of Delhi, his journey began,
# A boy with ambition, a future to span.
#
# With every run chased, with every sweet shot,
# He painted the canvas of cricket's great plot.
# A warrior in white, a king in the blue,
# Stitching the fabric of hope anew.
#
# His eyes held the fire, his spirit the flame,
# With grit and with grace, he earned all his fame.
# Records shattered, boundaries crossed,
# In moments of glory, not a detail lost.
#
# Through trials and triumphs, he stood ever tall,
# In the toughest of battles, he'd answer the call.
# For fans who believed, for passion untold,
# He played with a heart made of purest gold.
#
# A leader unyielding, with vision profound,
# He lifted the game, turned heads all around.
# With every captain’s armband, he carried the weight,
# Of hopes and dreams, in each thrilling fate.
#
# ...

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
os.environ["OPENAI_API_KEY"] = "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"  # Replace with your actual key
llm = ChatOpenAI(model="gpt-4o-mini")
prompt=ChatPromptTemplate.from_template("summarize this one line in one word")
chain=prompt|llm
print(chain.invoke({"text":"langachain is a framework used for gena ai "}))
# Out:
# content='Sure! Please provide the line you want summarized in one word.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 16, 'total_tokens': 29, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CZ5BdOBJs07CDj3qE30zDcgvkgmxp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--a7d61a5d-820c-46c7-95b8-5cbba6c5ee70-0' usage_metadata={'input_tokens': 16, 'output_tokens': 13, 'total_tokens': 29, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
